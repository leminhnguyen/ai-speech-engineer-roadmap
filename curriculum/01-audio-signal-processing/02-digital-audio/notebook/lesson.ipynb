# %% [markdown]
# # Digital Audio
#
# Use a known tone to make sampling and aliasing observable.

# %%
import sys
sys.path.insert(0, '../code')
from main import alias_frequency, dominant_frequency, sine_wave

tone = sine_wave(7_000, 10_000, 0.1)
alias_frequency(7_000, 10_000), dominant_frequency(tone, 10_000)

# %% [markdown]
# Change the sample rate and predict the result before you run the cell.
