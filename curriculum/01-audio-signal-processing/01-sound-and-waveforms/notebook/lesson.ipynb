# %% [markdown]
# # Sound and Waveforms
#
# Run the implementation, then change frequency, amplitude, and phase.

# %%
import sys
sys.path.insert(0, '../code')
from main import dominant_frequency, sine_wave

tone = sine_wave(440.0, 16_000, 0.25)
dominant_frequency(tone, 16_000)

# %% [markdown]
# Try `sine_wave(440.0, 16_000, 0.25, phase_radians=1.5708)` and compare it with `tone`.
